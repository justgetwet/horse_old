# %%
import pandas as pd
import numpy as np

col = ["月日", "G数", "当り", "出玉", "投資"]
g1 = ["1/23", 27, "0～ 宝蔵院胤舜 5R", 520, "-2,000円"]
g2 = ["", 133, "潜伏 絢爛 2R? 直Etr", np.nan , "-4,000円"]
g3 = ["", 26, "臥薪嘗胆 5R", 520, "" ]
g4 = ["", 293, "ヤメ", np.nan, "-7,000円"]
g5 = ["1/24", 127, "0～ 景勝&慶次 5R", 520, "-7,000円"]
g6 = ["", 2, "臥薪嘗胆 5R", 520, "" ]
g7 = ["", 169, "0～ 百花チャンス 胤舜 5R", 520, ""]
g8 = ["", 141, "ヤメ", np.nan, "-1,000円"]
g9 = ["", np.nan, "", np.nan, "計 -21,000円"]
lst = [g1, g2, g3, g4, g5, g6, g7, g8, g9]
_df = pd.DataFrame(lst, columns=col)
df = _df.astype({"G数": "object", "出玉": "object"}).\
style.set_properties(**{'text-align': 'right'})
print("百花繚乱 D492 21～2回/K")
df
# Out:
# 百花繚乱 D492 21～2回/K
# <style  type="text/css" >
#     #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row0_col0 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row0_col1 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row0_col2 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row0_col3 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row0_col4 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row1_col0 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row1_col1 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row1_col2 {
#             text-align:  right;
#         }    #T_d21c1398_3eb2_11ea_9c45_80ee73ab4cd3row1_col3 {
#             text-align:  right;
# ...

# %%
col = ["月日", "店台", "G数", "当り", "出玉", "投資"]
g1 = ["1/23", "D43", 182, "0～ 奇蹟の人 10R x 4連", 4625, "-10,000円"]
g2 = ["", "", np.nan, "", np.nan, "+18,500円"]
g3 = ["1/24", "M147白", 17, "0～ ヤメ", np.nan , "-1,000円"]
g4 = ["", "M146赤", 139, "0～ 金扉・紅天女 10R", 1220 , "-7,000円"]
g5 = ["", "", np.nan, "", np.nan, "+4,500円"]
g6 = ["", "", np.nan, "", np.nan, "計+5,000円"]
lst = [g1, g2, g3, g4, g5, g6]
_df = pd.DataFrame(lst, columns=col)
df = _df.astype({"G数": "object", "出玉": "object"}).\
style.set_properties(**{'text-align': 'right'})
print("ガラスの仮面 M22～4回/K")
df
# Out:
# ガラスの仮面 M22～4回/K
# <style  type="text/css" >
#     #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row0_col0 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row0_col1 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row0_col2 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row0_col3 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row0_col4 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row0_col5 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row1_col0 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row1_col1 {
#             text-align:  right;
#         }    #T_8d447dc8_3eb6_11ea_bc95_80ee73ab4cd3row1_col2 {
#             text-align:  right;
# ...

# %%
col = ["月日", "店台", "G数", "当り", "出玉", "投資"]
g1 = ["1/24", "K337", 321, "0～ ヤメ", 0, "-17,000円"]
lst = [g1]
_df = pd.DataFrame(lst, columns=col)
df = _df.astype({"G数": "object", "出玉": "object"}).\
style.set_properties(**{'text-align': 'right'})
print("偽物語199 20～2回/K")
df
# Out:
# 偽物語199 20～2回/K
# <style  type="text/css" >
#     #T_1a760ea4_3eb7_11ea_9614_80ee73ab4cd3row0_col0 {
#             text-align:  right;
#         }    #T_1a760ea4_3eb7_11ea_9614_80ee73ab4cd3row0_col1 {
#             text-align:  right;
#         }    #T_1a760ea4_3eb7_11ea_9614_80ee73ab4cd3row0_col2 {
#             text-align:  right;
#         }    #T_1a760ea4_3eb7_11ea_9614_80ee73ab4cd3row0_col3 {
#             text-align:  right;
#         }    #T_1a760ea4_3eb7_11ea_9614_80ee73ab4cd3row0_col4 {
#             text-align:  right;
#         }    #T_1a760ea4_3eb7_11ea_9614_80ee73ab4cd3row0_col5 {
#             text-align:  right;
# ...

# %%
col = ["月日", "店台", "G数", "当り", "出玉", "投資"]
g1 = ["1/24", "F沖桜", np.nan, "0～ 3台", 0, "-8,000円"]
g2 = ["", "F119(Black)", 183, "0～ ヤメ", 0, "-8,000円"]
g3 = ["", "", np.nan, "", np.nan, "計-16,000円"]
lst = [g1, g2, g3]
_df = pd.DataFrame(lst, columns=col)
df = _df.astype({"G数": "object", "出玉": "object"}).\
style.set_properties(**{'text-align': 'right'})
print("海物語Black 20～2回/K")
df
# Out:
# 海物語Black 20～2回/K
# <style  type="text/css" >
#     #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row0_col0 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row0_col1 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row0_col2 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row0_col3 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row0_col4 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row0_col5 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row1_col0 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row1_col1 {
#             text-align:  right;
#         }    #T_0a3aaf4c_3eb8_11ea_a03c_80ee73ab4cd3row1_col2 {
#             text-align:  right;
# ...

# %%
col = ["月日", "店台", "G数", "当り", "出玉", "投資"]
g1 = ["1/23", "D goJag", np.nan, "投資2K BIG", 312, "+4,000円"]
g2 = ["1/24", "M pulⅡ", np.nan, "投資1K BIG", 312, "+5,000円"]
g3 = ["", "M ｽﾄﾊﾟﾝ", np.nan, "余り玉オスイチ", 1300, "+5,000円"]
g4 = ["", "", np.nan, "", np.nan, "計+14,000円"]
lst = [g1, g2, g3, g4]
_df = pd.DataFrame(lst, columns=col)
df = _df.astype({"G数": "object", "出玉": "object"}).\
style.set_properties(**{'text-align': 'right'})
print("その他")
df
# Out:
# その他
# <style  type="text/css" >
#     #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row0_col0 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row0_col1 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row0_col2 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row0_col3 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row0_col4 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row0_col5 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row1_col0 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row1_col1 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row1_col2 {
#             text-align:  right;
#         }    #T_faa902fa_3eb8_11ea_b1d8_80ee73ab4cd3row1_col3 {
# ...
